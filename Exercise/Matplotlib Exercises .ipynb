# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
ax.plot(x,y,'b')
ax.set_ylim(0,200)
ax.set_xlim(0,100)
ax.set_xticks(np.linspace(0,100,6))
ax.set_yticks(np.linspace(0,200,6))
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.tick_params(direction='in')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax1.xaxis.set_ticks_position('both')
ax1.yaxis.set_ticks_position('both')
ax1.tick_params(direction='in')

ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax2.set_yticks(np.linspace(0,1,6))
ax2.set_xticks(np.linspace(0,1,6))
ax2.xaxis.set_ticks_position('both')
ax2.yaxis.set_ticks_position('both')
ax2.tick_params(direction='in')

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

ax1.plot(x,y,'r')
ax1.set_ylim(0,200)
ax1.set_xlim(0,100)
ax1.set_yticks(np.linspace(0,200,5))
ax2.set_xticks(np.linspace(0,100,6))
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.xaxis.set_ticks_position('both')
ax1.yaxis.set_ticks_position('both')
ax1.tick_params(direction='in')

ax2.plot(x,y,'r')
ax2.set_yticks(np.linspace(0,200,5))
ax2.set_xticks(np.linspace(0,100,6))
ax2.set_ylim(0,200)
ax2.set_xlim(0,100)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
#ax2.xaxis.set_ticks_position('both')
#ax2.yaxis.set_ticks_position('both')
ax2.tick_params(direction='in',right=True, top=True)

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax1.xaxis.set_ticks_position('both')
ax1.yaxis.set_ticks_position('both')
ax1.tick_params(direction='in')

ax2 = fig.add_axes([0.2,0.5,.4,.4])
ax2.set_yticks(np.linspace(0,1,6))
ax2.set_xticks(np.linspace(0,1,6))
ax2.xaxis.set_ticks_position('both')
ax2.yaxis.set_ticks_position('both')
ax2.tick_params(direction='in')

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig1 = plt.figure(1)
fig2 = plt.figure(2)
ax1 = fig1.add_axes([0,0,1,1])
ax1.plot(x,z,'b')
ax1.set_ylim(0,10000)
ax1.set_xlim(0,100)
ax1.set_yticks(np.linspace(0,10000,6))
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax1.xaxis.set_ticks_position('both')
ax1.yaxis.set_ticks_position('both')
ax1.tick_params(direction='in')

ax2 = fig1.add_axes([0.2,0.5,.4,.4])
ax2.plot(x,y,'b')
ax2.set_ylim(30,50)
ax2.set_xlim(20,22)
ax2.set_yticks(np.linspace(30,50,5))
ax2.set_xticks(np.linspace(20,22,5))
ax2.set_title('zoom')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.tick_params(direction='in',right=True, top=True)


ax1 = fig2.add_axes([0,0,1,1])
ax1.plot(x,z,'b')
ax1.set_ylim(0,10000)
ax1.set_xlim(0,100)
ax1.set_yticks(np.linspace(0,10000,6))
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax1.xaxis.set_ticks_position('both')
ax1.yaxis.set_ticks_position('both')
ax1.tick_params(direction='in')

ax2 = fig2.add_axes([0.2,0.5,.4,.4])
ax2.plot(x,y,'b')
ax2.set_ylim(30,50)
ax2.set_xlim(20,22)
ax2.set_yticks(np.linspace(30,50,5))
ax2.set_xticks(np.linspace(20,22,5))
ax2.set_title('zoom')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.tick_params(direction='in',right=True, top=True)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
for ax in axes:
    ax.tick_params(direction='in',right=True, top=True)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

ax2.plot(x,z,'r',lw=4, ls='-')
ax2.set_ylim(0,10000)
ax2.set_xlim(0,100)
ax2.set_yticks(np.linspace(0,10000,5))
ax2.set_xticks(np.linspace(0,100,6))
ax2.tick_params(direction='in',right=True, top=True)


line, = ax1.plot(x,y,color="blue", lw=3.5, ls='-')
line.set_dashes([2, 2]) # format: line length, space length, ...
ax1.set_ylim(0,200)
ax1.set_xlim(0,100)
ax1.set_yticks(np.linspace(0,200,5))
ax1.set_xticks(np.linspace(0,100,6))
ax1.tick_params(direction='in',right=True, top=True)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,2))

line, = ax2.plot(x,z,'r',lw=3, ls='-')
line.set_dashes([2.5,2])
ax2.set_ylim(0,10000)
ax2.set_xlim(0,100)
ax2.set_yticks(np.linspace(0,10000,5))
ax2.set_xticks(np.linspace(0,100,6))
ax2.tick_params(direction='in',right=True, top=True)


line, = ax1.plot(x,y,color="blue", lw=4.5, ls='-')
#line.set_dashes([2, 2]) # format: line length, space length, ...
ax1.set_ylim(0,200)
ax1.set_xlim(0,100)
ax1.set_yticks(np.linspace(0,200,5))
ax1.set_xticks(np.linspace(0,100,6))
ax1.tick_params(direction='in',right=True, top=True)

# %% [markdown]
# # Great Job!
